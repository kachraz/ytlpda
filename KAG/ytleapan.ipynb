# %% [markdown]
# <div style="background: url(https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExenVtNGVzaG45dmR2ejg3dGgweXF5MjdyYmtqM25wZnExMzZsaTFiOCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/xTiTnxpQ3ghPiB2Hp6/giphy.webp) repeat; color: #00ff00; padding: 2px; text-align: center;background-size: cover; text-shadow: 00 0 20px #ec4899">
#     <h1>Learning Pandas for DataAnalysis Starthere</h1>
#
# </div>
#
# 1. [`Colors`](https://rich.readthedocs.io/en/latest/appendix/colors.html?highlight=colors) _ list of standard colors that can be printed out
# 2. [`Ascii Banne Generator`](https://manytools.org/hacker-tools/ascii-banner/) - Used this to generate nice banners below
# 3. [`AsciiFlow`](https://asciiflow.com/#/) - Draw ASCII digrams you can then use this

# %% [markdown]
# <div style="background-color: #000502; color: #16a34a; padding: 10px; border-radius: 5px; font-size: 25px; text-align:center">
#   <a class="anchor" id="toc" style="text-decoration: none;">Table of Contents</a>
# </div>
#
# - ### [Lesson Summary](#s0)
# - ### [1-IntroPandasIntroPandas](#s1)
# - ### [2-I/O](#s2)
# - ### [3-DataFrameBsicsDataFrameBsics](#s3)
# - ### [4-FilteringData](#s4)
# - ### [5-SummarizingData ](#s5)
# - ### [6-AdvancedColumnMethods](#s6)
# - ### [7-RollingMethods](#s7)
# - ### [8-GroupbyMethods](#s8)
# - ### [9-NewColumns](#s9)
# - ### [10-SortData](#s10)
# - ### [11-SortingMissingData](#s11)
# - ### [12-CombiningData](#s12)
# - ### [13-MergeData](#s13)

# %%
# Prettify 
# Prettifyer code

# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
from rich.style import Style # For styles colors
from rich.text import Text # For text Styles
console = Console() # Standard code to access console
from rich.traceback import install
install(show_locals=True)
# -------------------------------------------------------
# Out:
# <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7e3cf4b02620>>

# %% [markdown]
# # Lesson Summary <a class="anchor" id="s0"></a> [↩️TOC](#toc)
#
# 1. This notebook is for woking on [`THIS`](https://youtu.be/DkjCaAMBGWM?si=wIPJl3W1pjocA_n3)
# 2. Used for data wrangling and data manipulation.

# %%
# Current Date Time 
import datetime

current_date = datetime.datetime.now()
rprint(current_date.strftime("%A, %B %d, %Y"))
# Out:
# Monday, July 29, 2024

# %% [markdown]
# # 1.IntroPandas <a class="anchor" id="s1"></a> [↩️TOC](#toc)

# %% [markdown]
# # Work with pandas
# - This will printout the pandas version
# - Printing both the python version and Pandas version
# - As of date of making this notebook the [`Pandas`](https://pandas.pydata.org/) version is - `2.2.2` - Same as the oen which this notebook uses

# %%
import pandas as pd 
import sys 

# Printing the python version
rprint(sys.version) 

# Printing the pandas version
rprint('Pandas Kag Version:- ',pd.__version__)
# Out:
# 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Pandas Kag Version:-  2.2.2

# %% [markdown]
# # 2.I/O <a class="anchor" id="s2"></a> [↩️TOC](#toc)
#
# 1. `pd.read_csv` - Most used option
# 2. Note the tutorial works with parquet files , so have to first get some parquet files and then continue
# 3. [`Tutorial Notebook`](https://www.kaggle.com/code/lizhecheng/pandas-2-0-1-tutorial/notebook) - This is the tutorial notebook with the data set which is being used in this course. Will dl file , and ul to gh , then use remote load from addinput
# - This above notebook actually is using kaggle datasets which have the parquet format
# 4. Dataset being used
#     1. (`inflight-emergency-situations`)[https://www.kaggle.com/datasets/ahmedeltom/inflight-emergency-situations-20182020]

# %% [markdown]
# - This above library was mentioned in the dataset to install

# %%
# Reading the dataset
df = pd.read_parquet('/kaggle/input/inflight-emergency-situations-20182020/trajectories.parquet')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Coversion of the parquet dataset to csv

# %% [markdown]
# # 2.DataFrameBsics <a class="anchor" id="s3"></a> [↩️TOC](#toc)

# %%
# Viw first 5 rows 
df.head()
# Out:
#                   timestamp  altitude callsign         flight_id  groundspeed  \
# 0 2018-01-01 12:29:49+00:00   11300.0  ARG1511  ARG1511_20180101   309.885195
# 1 2018-01-01 12:29:50+00:00   11375.0  ARG1511  ARG1511_20180101   310.264709
# 2 2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101   310.644223
# 3 2018-01-01 12:29:52+00:00   11500.0  ARG1511  ARG1511_20180101   311.192793
# 4 2018-01-01 12:29:53+00:00   11550.0  ARG1511  ARG1511_20180101   311.741363
#
#    icao24   latitude  longitude squawk       track  vertical_rate
# 0  e06442 -31.449051 -63.963318   7700  130.441641    3008.000000
# 1  e06442 -31.450453 -63.961432   7700  130.441641    3040.000000
# 2  e06442 -31.451856 -63.959546   7700  130.441641    3072.000000
# 3  e06442 -31.452843 -63.958193   7700  130.440361    3074.742857
# 4  e06442 -31.453831 -63.956840   7700  130.439081    3077.485714

# %%
# settign the columns size 
pd.set_option('display.max_columns', 500)

# %%
df.head()
# Out:
#                   timestamp  altitude callsign         flight_id  groundspeed  \
# 0 2018-01-01 12:29:49+00:00   11300.0  ARG1511  ARG1511_20180101   309.885195
# 1 2018-01-01 12:29:50+00:00   11375.0  ARG1511  ARG1511_20180101   310.264709
# 2 2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101   310.644223
# 3 2018-01-01 12:29:52+00:00   11500.0  ARG1511  ARG1511_20180101   311.192793
# 4 2018-01-01 12:29:53+00:00   11550.0  ARG1511  ARG1511_20180101   311.741363
#
#    icao24   latitude  longitude squawk       track  vertical_rate
# 0  e06442 -31.449051 -63.963318   7700  130.441641    3008.000000
# 1  e06442 -31.450453 -63.961432   7700  130.441641    3040.000000
# 2  e06442 -31.451856 -63.959546   7700  130.441641    3072.000000
# 3  e06442 -31.452843 -63.958193   7700  130.440361    3074.742857
# 4  e06442 -31.453831 -63.956840   7700  130.439081    3077.485714

# %% [markdown]
#  Viewing the first 20 columns

# %%
df.head(20)
# Out:
#                    timestamp  altitude callsign         flight_id  \
# 0  2018-01-01 12:29:49+00:00   11300.0  ARG1511  ARG1511_20180101
# 1  2018-01-01 12:29:50+00:00   11375.0  ARG1511  ARG1511_20180101
# 2  2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101
# 3  2018-01-01 12:29:52+00:00   11500.0  ARG1511  ARG1511_20180101
# 4  2018-01-01 12:29:53+00:00   11550.0  ARG1511  ARG1511_20180101
# 5  2018-01-01 12:29:54+00:00   11600.0  ARG1511  ARG1511_20180101
# 6  2018-01-01 12:29:55+00:00   11650.0  ARG1511  ARG1511_20180101
# 7  2018-01-01 12:29:56+00:00   11700.0  ARG1511  ARG1511_20180101
# 8  2018-01-01 12:29:57+00:00   11750.0  ARG1511  ARG1511_20180101
# 9  2018-01-01 12:29:58+00:00   11800.0  ARG1511  ARG1511_20180101
# 10 2018-01-01 12:29:59+00:00   11850.0  ARG1511  ARG1511_20180101
# 11 2018-01-01 12:30:00+00:00   11900.0  ARG1511  ARG1511_20180101
# 12 2018-01-01 12:30:01+00:00   11950.0  ARG1511  ARG1511_20180101
# ...

# %% [markdown]
# Pulling the last 10 columns

# %%
df.tail(10)
# Out:
#                         timestamp    altitude callsign         flight_id  \
# 4344349 2020-01-29 04:09:43+00:00  659.375000  ASH6299  ASH6299_20200129
# 4344350 2020-01-29 04:09:44+00:00  658.333333  ASH6299  ASH6299_20200129
# 4344351 2020-01-29 04:09:45+00:00  657.291667  ASH6299  ASH6299_20200129
# 4344352 2020-01-29 04:09:46+00:00  656.250000  ASH6299  ASH6299_20200129
# 4344353 2020-01-29 04:09:47+00:00  655.208333  ASH6299  ASH6299_20200129
# 4344354 2020-01-29 04:09:48+00:00  654.166667  ASH6299  ASH6299_20200129
# 4344355 2020-01-29 04:09:49+00:00  653.125000  ASH6299  ASH6299_20200129
# 4344356 2020-01-29 04:09:50+00:00  652.083333  ASH6299  ASH6299_20200129
# 4344357 2020-01-29 04:09:51+00:00  651.041667  ASH6299  ASH6299_20200129
# 4344358 2020-01-29 04:09:52+00:00  650.000000  ASH6299  ASH6299_20200129
#
#          groundspeed  icao24   latitude  longitude squawk       track  \
# 4344349   137.440778  ac2bb8  40.002629 -82.897304   2756  274.590543
# ...

# %% [markdown]
# Pulling a random sample from the rowns list
# - Note this will pull a random et

# %%
df.sample(5)
# Out:
#                         timestamp      altitude callsign         flight_id  \
# 1093031 2018-09-11 09:44:28+00:00  22000.000000   BEL515   BEL515_20180911
# 2795881 2019-06-24 07:11:32+00:00  35012.126246   NKS970   NKS970_20190624
# 3525248 2019-09-26 17:46:55+00:00  21950.000000   ASA976   ASA976_20190926
# 3974199 2019-12-03 20:38:55+00:00  36000.000000  RPA3552  RPA3552_20191203
# 2075362 2019-03-12 13:26:36+00:00  36025.000000   FDX458   FDX458_20190312
#
#          groundspeed  icao24   latitude   longitude squawk       track  \
# 1093031   418.054659  44ccd5  51.396510   -1.158981   7700  108.391641
# 2795881   444.763001  a6464b  37.055723  -95.945977   0614  118.323227
# 3525248   478.037242  a360e3  46.658432 -121.734076   1647  126.150742
# 3974199   385.439675  a866c7  37.084465  -87.170071   7700  231.108038
# 2075362   384.689153  a03423  29.961731  -83.652326   4054  326.144458
#
#          vertical_rate
# 1093031     -64.000000
# 2795881      63.362126
# ...

# %% [markdown]
# Setting a random state for pulling the same

# %%
df.sample(frac=0.0001)
# Out:
#                         timestamp      altitude callsign         flight_id  \
# 774792  2018-06-30 08:16:20+00:00  35000.000000   DAL819   DAL819_20180630
# 4330097 2020-01-29 01:12:56+00:00  37000.000000  SWA2192  SWA2192_20200129
# 2906773 2019-07-08 23:36:06+00:00  34565.711136  AAL1895  AAL1895_20190708
# 1950301 2019-02-22 18:42:43+00:00  32000.000000   SWA597   SWA597_20190222
# 3683383 2019-10-26 22:02:24+00:00   7125.000000  RRR4055  RRR4055_20191026
# ...                           ...           ...      ...               ...
# 2170692 2019-03-28 00:06:56+00:00  36000.000000  SWA2184  SWA2184_20190327
# 3463844 2019-09-17 07:36:46+00:00   8175.000000  AXG1801  AXG1801_20190917
# 1815695 2019-01-28 14:35:35+00:00  43000.000000   EJA404   EJA404_20190128
# 1093259 2018-09-11 09:48:16+00:00  22000.000000   BEL515   BEL515_20180911
# 3040794 2019-07-24 22:24:40+00:00  38000.000000   DLH469   DLH469_20190724
#
# ...

# %% [markdown]
# For reporoducability using the `random_state=XX` ensures the same sample being produced everytime. This is for reproducability of the random data set

# %%
df.sample(10, random_state=69)
# Out:
#                         timestamp      altitude callsign         flight_id  \
# 2463923 2019-05-09 22:28:16+00:00   3150.000000   TUI6YX   TUI6YX_20190509
# 2118286 2019-03-17 15:32:44+00:00  12450.000000   AAL163   AAL163_20190317
# 3876186 2019-11-21 13:55:23+00:00  12550.000000  SKW5639  SKW5639_20191121
# 31081   2018-01-08 03:59:14+00:00  32000.000000    DAL65    DAL65_20180108
# 1554593 2018-12-06 14:34:46+00:00  37000.000000  ABY1692  ABY1692_20181206
# 628528  2018-06-05 07:08:42+00:00  36975.000000   AAL213   AAL213_20180605
# 1302600 2018-10-23 09:40:04+00:00  32000.000000   EVA011   EVA011_20181023
# 3179997 2019-08-13 08:50:05+00:00  37975.000000  RAM718D  RAM718D_20190813
# 780071  2018-06-30 09:44:43+00:00  34950.000000   DAL819   DAL819_20180630
# 2893199 2019-07-08 18:53:11+00:00  27616.666667  JIA5116  JIA5116_20190708
#
#          groundspeed  icao24   latitude   longitude squawk       track  \
# ...

# %%
# View only columns 
df.columns
# Out:
# Index(['timestamp', 'altitude', 'callsign', 'flight_id', 'groundspeed',
#        'icao24', 'latitude', 'longitude', 'squawk', 'track', 'vertical_rate'],
#       dtype='object')

# %%
# View Index
df.index
# df2.index
# Out:
# RangeIndex(start=0, stop=4344359, step=1)

# %% [markdown]
# View information about the dataset,
# - `verbose=True` - Gives more detailed information

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4344359 entries, 0 to 4344358
# Columns: 11 entries, timestamp to vertical_rate
# dtypes: datetime64[us, UTC](1), float64(6), object(4)
# memory usage: 364.6+ MB

# %% [markdown]
# ## 2.1 DescriptiveStatistics <a class="anchor" id="s4"></a> [↩️TOC](#toc)

# %%
# gettingg descriptive statistics 

df.describe()
# Out:
#            altitude   groundspeed      latitude     longitude         track  \
# count  4.344359e+06  4.307312e+06  4.344359e+06  4.344359e+06  4.307312e+06
# mean   2.653439e+04  3.944624e+02  4.010783e+01 -4.393507e+01  1.927143e+02
# std    1.212769e+04  1.285338e+02  1.492686e+01  5.537757e+01  1.062650e+02
# min   -5.750000e+02  2.828425e+00 -3.866559e+01 -1.565582e+02  0.000000e+00
# 25%    1.647500e+04  3.398423e+02  3.549571e+01 -9.158867e+01  9.294816e+01
# 50%    3.200000e+04  4.186379e+02  4.220419e+01 -6.188072e+01  2.094500e+02
# 75%    3.600000e+04  4.637420e+02  4.920561e+01  1.862626e+00  2.851302e+02
# max    1.155000e+05  4.535941e+03  6.682288e+01  1.764965e+02  3.600000e+02
#
#        vertical_rate
# count   4.307312e+06
# mean   -3.354702e+01
# std     1.772641e+03
# min    -2.302500e+05
# 25%    -6.400000e+01
# 50%     0.000000e+00
# 75%     0.000000e+00
# max     1.235200e+04

# %% [markdown]
# ## Describing a non number column
# - Gives some helpful stats

# %%
# Running describe on non numeric values 
df[['callsign']].describe()
# Out:
#        callsign
# count   4344359
# unique      823
# top     ASR172B
# freq      22825

# %% [markdown]
# Shape - This gives the rows and columns

# %%
# Getting shape of data 
df.shape
# Out:
# (4344359, 11)

# %%
df.shape, len(df)
# Out:
# ((4344359, 11), 4344359)

# %% [markdown]
# ## Subsetting a dataframe
# - This is extracting rows

# %%
df_subset = df[['callsign']]

# %%
df_subset.describe()
# Out:
#        callsign
# count   4344359
# unique      823
# top     ASR172B
# freq      22825

# %%
df_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4344359 entries, 0 to 4344358
# Data columns (total 1 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   callsign  object
# dtypes: object(1)
# memory usage: 33.1+ MB

# %%
df[['callsign', 'flight_id']]
# Out:
#         callsign         flight_id
# 0        ARG1511  ARG1511_20180101
# 1        ARG1511  ARG1511_20180101
# 2        ARG1511  ARG1511_20180101
# 3        ARG1511  ARG1511_20180101
# 4        ARG1511  ARG1511_20180101
# ...          ...               ...
# 4344354  ASH6299  ASH6299_20200129
# 4344355  ASH6299  ASH6299_20200129
# 4344356  ASH6299  ASH6299_20200129
# 4344357  ASH6299  ASH6299_20200129
# 4344358  ASH6299  ASH6299_20200129
#
# [4344359 rows x 2 columns]

# %% [markdown]
# # Getting the columns

# %%
df[df.columns[:2]]
# Out:
#                         timestamp      altitude
# 0       2018-01-01 12:29:49+00:00  11300.000000
# 1       2018-01-01 12:29:50+00:00  11375.000000
# 2       2018-01-01 12:29:51+00:00  11450.000000
# 3       2018-01-01 12:29:52+00:00  11500.000000
# 4       2018-01-01 12:29:53+00:00  11550.000000
# ...                           ...           ...
# 4344354 2020-01-29 04:09:48+00:00    654.166667
# 4344355 2020-01-29 04:09:49+00:00    653.125000
# 4344356 2020-01-29 04:09:50+00:00    652.083333
# 4344357 2020-01-29 04:09:51+00:00    651.041667
# 4344358 2020-01-29 04:09:52+00:00    650.000000
#
# [4344359 rows x 2 columns]

# %% [markdown]
# The following will just get you the nams of the columsn , if you want to subset you have to use the above syntax

# %%
df.columns[1:3]
# Out:
# Index(['altitude', 'callsign'], dtype='object')

# %%
# getting the last 5 columns 

df[df.columns[-2:]]
# Out:
#               track  vertical_rate
# 0        130.441641    3008.000000
# 1        130.441641    3040.000000
# 2        130.441641    3072.000000
# 3        130.440361    3074.742857
# 4        130.439081    3077.485714
# ...             ...            ...
# 4344354  274.590543    -704.000000
# 4344355  274.590543    -704.000000
# 4344356  274.590543    -704.000000
# 4344357  274.590543    -704.000000
# 4344358  274.590543    -704.000000
#
# [4344359 rows x 2 columns]

# %% [markdown]
# ## List comprehension
# - this is for getting those columns with specific names

# %%
# List comprehension 
df[[c for c in df.columns if 'sign' in c]]
# Out:
#         callsign
# 0        ARG1511
# 1        ARG1511
# 2        ARG1511
# 3        ARG1511
# 4        ARG1511
# ...          ...
# 4344354  ASH6299
# 4344355  ASH6299
# 4344356  ASH6299
# 4344357  ASH6299
# 4344358  ASH6299
#
# [4344359 rows x 1 columns]

# %% [markdown]
# ## Seleting only integers with
#
# ```py
# df.select_dtypes('int')
# ```
#
# Pandas recognizes several data type categories, including:
#
# 1. 'number': All numeric types (int, float, etc.)
# 2. 'integer': Integer types (int64, int32, etc.)
# 3. 'floating': Floating-point types (float64, float32, etc.)
# 4. 'object': String and mixed types (usually strings)
# 5. 'bool': Boolean types
# 6. 'datetime': Datetime types
# 7. 'timedelta': Timedelta types
# 8. 'category': Categorical types

# %%
df.select_dtypes('floating')
# Out:
#              altitude  groundspeed   latitude  longitude       track  \
# 0        11300.000000   309.885195 -31.449051 -63.963318  130.441641
# 1        11375.000000   310.264709 -31.450453 -63.961432  130.441641
# 2        11450.000000   310.644223 -31.451856 -63.959546  130.441641
# 3        11500.000000   311.192793 -31.452843 -63.958193  130.440361
# 4        11550.000000   311.741363 -31.453831 -63.956840  130.439081
# ...               ...          ...        ...        ...         ...
# 4344354    654.166667   137.440778  40.002762 -82.899621  274.590543
# 4344355    653.125000   137.440778  40.002789 -82.900084  274.590543
# 4344356    652.083333   137.440778  40.002816 -82.900547  274.590543
# 4344357    651.041667   137.440778  40.002842 -82.901011  274.590543
# 4344358    650.000000   137.440778  40.002869 -82.901474  274.590543
#
#          vertical_rate
# 0          3008.000000
# 1          3040.000000
# 2          3072.000000
# 3          3074.742857
# ...

# %% [markdown]
# Selecting Column  - Series of that column

# %%
df['callsign']
# Out:
# 0          ARG1511
# 1          ARG1511
# 2          ARG1511
# 3          ARG1511
# 4          ARG1511
#             ...
# 4344354    ASH6299
# 4344355    ASH6299
# 4344356    ASH6299
# 4344357    ASH6299
# 4344358    ASH6299
# Name: callsign, Length: 4344359, dtype: object

# %%
# This will give a data fram 
df[['callsign']]
# Out:
#         callsign
# 0        ARG1511
# 1        ARG1511
# 2        ARG1511
# 3        ARG1511
# 4        ARG1511
# ...          ...
# 4344354  ASH6299
# 4344355  ASH6299
# 4344356  ASH6299
# 4344357  ASH6299
# 4344358  ASH6299
#
# [4344359 rows x 1 columns]

# %% [markdown]
# # 4 - FilteringData <a class="anchor" id="s4"></a> [↩️TOC](#toc)

# %% [markdown]
# 1. Accessing data in data frame based on their location
#
# `df.loc[]` = Uses Names
# `df.iloc[]` = Uses location

# %%
df.head()
# Out:
#                   timestamp  altitude callsign         flight_id  groundspeed  \
# 0 2018-01-01 12:29:49+00:00   11300.0  ARG1511  ARG1511_20180101   309.885195
# 1 2018-01-01 12:29:50+00:00   11375.0  ARG1511  ARG1511_20180101   310.264709
# 2 2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101   310.644223
# 3 2018-01-01 12:29:52+00:00   11500.0  ARG1511  ARG1511_20180101   311.192793
# 4 2018-01-01 12:29:53+00:00   11550.0  ARG1511  ARG1511_20180101   311.741363
#
#    icao24   latitude  longitude squawk       track  vertical_rate
# 0  e06442 -31.449051 -63.963318   7700  130.441641    3008.000000
# 1  e06442 -31.450453 -63.961432   7700  130.441641    3040.000000
# 2  e06442 -31.451856 -63.959546   7700  130.441641    3072.000000
# 3  e06442 -31.452843 -63.958193   7700  130.440361    3074.742857
# 4  e06442 -31.453831 -63.956840   7700  130.439081    3077.485714

# %%
# Subsetting column and row 
df.iloc[:5, :3]
# Out:
#                   timestamp  altitude callsign
# 0 2018-01-01 12:29:49+00:00   11300.0  ARG1511
# 1 2018-01-01 12:29:50+00:00   11375.0  ARG1511
# 2 2018-01-01 12:29:51+00:00   11450.0  ARG1511
# 3 2018-01-01 12:29:52+00:00   11500.0  ARG1511
# 4 2018-01-01 12:29:53+00:00   11550.0  ARG1511

# %%
# Extracting a specific value 
df.iloc[0,8]
# Out:
# '7700'

# %%
# Filtering to the row - meaning pulling one row out - here it is row3
df.iloc[3]
# Out:
# timestamp        2018-01-01 12:29:52+00:00
# altitude                           11500.0
# callsign                           ARG1511
# flight_id                 ARG1511_20180101
# groundspeed                     311.192793
# icao24                              e06442
# latitude                        -31.452843
# longitude                       -63.958193
# squawk                                7700
# track                           130.440361
# vertical_rate                  3074.742857
# Name: 3, dtype: object

# %%
df.iloc[0] # When you pull row 0 you will get he first row
# Out:
# timestamp        2018-01-01 12:29:49+00:00
# altitude                           11300.0
# callsign                           ARG1511
# flight_id                 ARG1511_20180101
# groundspeed                     309.885195
# icao24                              e06442
# latitude                        -31.449051
# longitude                       -63.963318
# squawk                                7700
# track                           130.441641
# vertical_rate                       3008.0
# Name: 0, dtype: object

# %%
# Pulling row as a data frame
df.iloc[[2]]
# Out:
#                   timestamp  altitude callsign         flight_id  groundspeed  \
# 2 2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101   310.644223
#
#    icao24   latitude  longitude squawk       track  vertical_rate
# 2  e06442 -31.451856 -63.959546   7700  130.441641         3072.0

# %%
# Filter only 1st column 
df.iloc[:, 1]
# Out:
# 0          11300.000000
# 1          11375.000000
# 2          11450.000000
# 3          11500.000000
# 4          11550.000000
#                ...
# 4344354      654.166667
# 4344355      653.125000
# 4344356      652.083333
# 4344357      651.041667
# 4344358      650.000000
# Name: altitude, Length: 4344359, dtype: float64

# %%
# Filter 1st and 2nd column  
df.iloc[:, [1,2]]
# Out:
#              altitude callsign
# 0        11300.000000  ARG1511
# 1        11375.000000  ARG1511
# 2        11450.000000  ARG1511
# 3        11500.000000  ARG1511
# 4        11550.000000  ARG1511
# ...               ...      ...
# 4344354    654.166667  ASH6299
# 4344355    653.125000  ASH6299
# 4344356    652.083333  ASH6299
# 4344357    651.041667  ASH6299
# 4344358    650.000000  ASH6299
#
# [4344359 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4344359 entries, 0 to 4344358
# Data columns (total 11 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   timestamp      datetime64[us, UTC]
#  1   altitude       float64
#  2   callsign       object
#  3   flight_id      object
#  4   groundspeed    float64
#  5   icao24         object
#  6   latitude       float64
#  7   longitude      float64
#  8   squawk         object
#  9   track          float64
#  10  vertical_rate  float64
# dtypes: datetime64[us, UTC](1), float64(6), object(4)
# memory usage: 364.6+ MB

# %%
# Filter 1st and 2nd column  
df.loc[:, ['callsign', 'track']]
# Out:
#         callsign       track
# 0        ARG1511  130.441641
# 1        ARG1511  130.441641
# 2        ARG1511  130.441641
# 3        ARG1511  130.440361
# 4        ARG1511  130.439081
# ...          ...         ...
# 4344354  ASH6299  274.590543
# 4344355  ASH6299  274.590543
# 4344356  ASH6299  274.590543
# 4344357  ASH6299  274.590543
# 4344358  ASH6299  274.590543
#
# [4344359 rows x 2 columns]

# %% [markdown]
# Using `df.loc` to get a boolean on the existence of a condition

# %%
# Using loc - filer on boolean expression 
df[['callsign']] == 'ARG1511'
# Out:
#          callsign
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
# ...           ...
# 4344354     False
# 4344355     False
# 4344356     False
# 4344357     False
# 4344358     False
#
# [4344359 rows x 1 columns]

# %%
# Using boolen query  - using double condition
df.query('(track > 130) and (altitude < 11000)')
# Out:
#                         timestamp     altitude callsign         flight_id  \
# 2657    2018-01-01 13:14:46+00:00  2575.000000  ARG1511  ARG1511_20180101
# 2658    2018-01-01 13:14:47+00:00  2575.000000  ARG1511  ARG1511_20180101
# 2659    2018-01-01 13:14:48+00:00  2575.000000  ARG1511  ARG1511_20180101
# 2660    2018-01-01 13:14:49+00:00  2575.000000  ARG1511  ARG1511_20180101
# 2661    2018-01-01 13:14:50+00:00  2575.000000  ARG1511  ARG1511_20180101
# ...                           ...          ...      ...               ...
# 4344354 2020-01-29 04:09:48+00:00   654.166667  ASH6299  ASH6299_20200129
# 4344355 2020-01-29 04:09:49+00:00   653.125000  ASH6299  ASH6299_20200129
# 4344356 2020-01-29 04:09:50+00:00   652.083333  ASH6299  ASH6299_20200129
# 4344357 2020-01-29 04:09:51+00:00   651.041667  ASH6299  ASH6299_20200129
# 4344358 2020-01-29 04:09:52+00:00   650.000000  ASH6299  ASH6299_20200129
#
#          groundspeed  icao24   latitude  longitude squawk       track  \
# ...

# %% [markdown]
# # 5 - SummarizingData <a class="anchor" id="s5"></a> [↩️TOC](#toc)

# %%
df.head()
# Out:
#                   timestamp  altitude callsign         flight_id  groundspeed  \
# 0 2018-01-01 12:29:49+00:00   11300.0  ARG1511  ARG1511_20180101   309.885195
# 1 2018-01-01 12:29:50+00:00   11375.0  ARG1511  ARG1511_20180101   310.264709
# 2 2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101   310.644223
# 3 2018-01-01 12:29:52+00:00   11500.0  ARG1511  ARG1511_20180101   311.192793
# 4 2018-01-01 12:29:53+00:00   11550.0  ARG1511  ARG1511_20180101   311.741363
#
#    icao24   latitude  longitude squawk       track  vertical_rate
# 0  e06442 -31.449051 -63.963318   7700  130.441641    3008.000000
# 1  e06442 -31.450453 -63.961432   7700  130.441641    3040.000000
# 2  e06442 -31.451856 -63.959546   7700  130.441641    3072.000000
# 3  e06442 -31.452843 -63.958193   7700  130.440361    3074.742857
# 4  e06442 -31.453831 -63.956840   7700  130.439081    3077.485714

# %%
df.describe()
# Out:
#            altitude   groundspeed      latitude     longitude         track  \
# count  4.344359e+06  4.307312e+06  4.344359e+06  4.344359e+06  4.307312e+06
# mean   2.653439e+04  3.944624e+02  4.010783e+01 -4.393507e+01  1.927143e+02
# std    1.212769e+04  1.285338e+02  1.492686e+01  5.537757e+01  1.062650e+02
# min   -5.750000e+02  2.828425e+00 -3.866559e+01 -1.565582e+02  0.000000e+00
# 25%    1.647500e+04  3.398423e+02  3.549571e+01 -9.158867e+01  9.294816e+01
# 50%    3.200000e+04  4.186379e+02  4.220419e+01 -6.188072e+01  2.094500e+02
# 75%    3.600000e+04  4.637420e+02  4.920561e+01  1.862626e+00  2.851302e+02
# max    1.155000e+05  4.535941e+03  6.682288e+01  1.764965e+02  3.600000e+02
#
#        vertical_rate
# count   4.307312e+06
# mean   -3.354702e+01
# std     1.772641e+03
# min    -2.302500e+05
# 25%    -6.400000e+01
# 50%     0.000000e+00
# 75%     0.000000e+00
# max     1.235200e+04

# %% [markdown]
# Methods on single or multipm columns
# 1. Mean
# 2. Max
# 3. Min
# 4. std deviation
# 5. Sum
# 6. Quantile
# b

# %%
# for the column
df['groundspeed'].mean()
# Out:
# 394.46241008194414

# %%
df['groundspeed'].max()
# Out:
# 4535.941407205894

# %%
df['groundspeed'].min()
# Out:
# 2.8284246811806395

# %%
df['groundspeed'].std()
# Out:
# 128.53378835679356

# %%
df['groundspeed'].sum()
# Out:
# 1699072672.494879

# %%
df['groundspeed'].quantile([0.25, 0.75])
# Out:
# 0.25    339.842317
# 0.75    463.741985
# Name: groundspeed, dtype: float64

# %% [markdown]
# Running multiple methods on a column or group of columns

# %%
df.head()
# Out:
#                   timestamp  altitude callsign         flight_id  groundspeed  \
# 0 2018-01-01 12:29:49+00:00   11300.0  ARG1511  ARG1511_20180101   309.885195
# 1 2018-01-01 12:29:50+00:00   11375.0  ARG1511  ARG1511_20180101   310.264709
# 2 2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101   310.644223
# 3 2018-01-01 12:29:52+00:00   11500.0  ARG1511  ARG1511_20180101   311.192793
# 4 2018-01-01 12:29:53+00:00   11550.0  ARG1511  ARG1511_20180101   311.741363
#
#    icao24   latitude  longitude squawk       track  vertical_rate
# 0  e06442 -31.449051 -63.963318   7700  130.441641    3008.000000
# 1  e06442 -31.450453 -63.961432   7700  130.441641    3040.000000
# 2  e06442 -31.451856 -63.959546   7700  130.441641    3072.000000
# 3  e06442 -31.452843 -63.958193   7700  130.440361    3074.742857
# 4  e06442 -31.453831 -63.956840   7700  130.439081    3077.485714

# %% [markdown]
# The following is for running multipple stats on multiple columns

# %%
df[['altitude', 'groundspeed', 'vertical_rate']].agg(['mean', 'max', 'min'])
# Out:
#           altitude  groundspeed  vertical_rate
# mean   26534.39017   394.462410     -33.547017
# max   115500.00000  4535.941407   12352.000000
# min     -575.00000     2.828425 -230250.000000

# %%
df.describe()
# Out:
#            altitude   groundspeed      latitude     longitude         track  \
# count  4.344359e+06  4.307312e+06  4.344359e+06  4.344359e+06  4.307312e+06
# mean   2.653439e+04  3.944624e+02  4.010783e+01 -4.393507e+01  1.927143e+02
# std    1.212769e+04  1.285338e+02  1.492686e+01  5.537757e+01  1.062650e+02
# min   -5.750000e+02  2.828425e+00 -3.866559e+01 -1.565582e+02  0.000000e+00
# 25%    1.647500e+04  3.398423e+02  3.549571e+01 -9.158867e+01  9.294816e+01
# 50%    3.200000e+04  4.186379e+02  4.220419e+01 -6.188072e+01  2.094500e+02
# 75%    3.600000e+04  4.637420e+02  4.920561e+01  1.862626e+00  2.851302e+02
# max    1.155000e+05  4.535941e+03  6.682288e+01  1.764965e+02  3.600000e+02
#
#        vertical_rate
# count   4.307312e+06
# mean   -3.354702e+01
# std     1.772641e+03
# min    -2.302500e+05
# 25%    -6.400000e+01
# 50%     0.000000e+00
# 75%     0.000000e+00
# max     1.235200e+04

# %% [markdown]
# `agg` method cna also take a dictionary for extracting specific insights on speficif columns

# %%
df[['altitude', 'groundspeed', 'vertical_rate']].agg(
{
    'altitude': ['min', 'max'],
    'groundspeed': ['mean'],
    'vertical_rate': ['min', 'max']    
})
# Out:
#       altitude  groundspeed  vertical_rate
# min     -575.0          NaN      -230250.0
# max   115500.0          NaN        12352.0
# mean       NaN    394.46241            NaN

# %% [markdown]
# ## Summarizing Categoircal Variables

# %%
df['altitude'].unique()
# Out:
# array([11300.        , 11375.        , 11450.        , ...,
#          653.125     ,   652.08333333,   651.04166667])

# %% [markdown]
# Then the number of unique values

# %%
df['callsign'].nunique()
# Out:
# 823

# %%
# Value Counts 
df['callsign'].value_counts()
# Out:
# callsign
# ASR172B    22825
# UAL275     19812
# AAL578     18812
# UAE15      18220
# UAL1827    18150
#            ...
# MRA655       232
# QID294       168
# KLM85R        70
# HDA391        53
# EZY43YH       33
# Name: count, Length: 823, dtype: int64

# %%
dfcv = df['callsign'].value_counts()
dfcv.to_frame()
# Out:
#           count
# callsign
# ASR172B   22825
# UAL275    19812
# AAL578    18812
# UAE15     18220
# UAL1827   18150
# ...         ...
# MRA655      232
# QID294      168
# KLM85R       70
# HDA391       53
# EZY43YH      33
#
# [823 rows x 1 columns]

# %%
# Above code in a single line 

df['callsign'].value_counts().to_frame()
# Out:
#           count
# callsign
# ASR172B   22825
# UAL275    19812
# AAL578    18812
# UAE15     18220
# UAL1827   18150
# ...         ...
# MRA655      232
# QID294      168
# KLM85R       70
# HDA391       53
# EZY43YH      33
#
# [823 rows x 1 columns]

# %%
# Getting fractions 
df['callsign'].value_counts(normalize=True).to_frame()
# Out:
#           proportion
# callsign
# ASR172B     0.005254
# UAL275      0.004560
# AAL578      0.004330
# UAE15       0.004194
# UAL1827     0.004178
# ...              ...
# MRA655      0.000053
# QID294      0.000039
# KLM85R      0.000016
# HDA391      0.000012
# EZY43YH     0.000008
#
# [823 rows x 1 columns]

# %% [markdown]
# Uusing `.reset_index()` you can get a dataframe

# %%
df['callsign'].value_counts().reset_index()
# Out:
#     callsign  count
# 0    ASR172B  22825
# 1     UAL275  19812
# 2     AAL578  18812
# 3      UAE15  18220
# 4    UAL1827  18150
# ..       ...    ...
# 818   MRA655    232
# 819   QID294    168
# 820   KLM85R     70
# 821   HDA391     53
# 822  EZY43YH     33
#
# [823 rows x 2 columns]

# %%
df['callsign'].value_counts(normalize=True).to_frame()
# Out:
#           proportion
# callsign
# ASR172B     0.005254
# UAL275      0.004560
# AAL578      0.004330
# UAE15       0.004194
# UAL1827     0.004178
# ...              ...
# MRA655      0.000053
# QID294      0.000039
# KLM85R      0.000016
# HDA391      0.000012
# EZY43YH     0.000008
#
# [823 rows x 1 columns]

# %% [markdown]
# Runing value counts and to frame on multple columns

# %%
df[['callsign', 'altitude']].value_counts().to_frame()
# Out:
#                    count
# callsign altitude
# PIA709   34000.0   14762
# ASR172B  26975.0   10968
# DLH469   37000.0   10725
# JKR85    40000.0    9732
# SWG521   36000.0    9681
# ...                  ...
# EZY84ZA  19150.0       1
#          19175.0       1
#          19200.0       1
#          19225.0       1
# AAL110   2500.0        1
#
# [1247623 rows x 1 columns]

# %%
# Using reset index to get a data frame 
df[['callsign', 'altitude']].value_counts().reset_index()
# Out:
#         callsign  altitude  count
# 0         PIA709   34000.0  14762
# 1        ASR172B   26975.0  10968
# 2         DLH469   37000.0  10725
# 3          JKR85   40000.0   9732
# 4         SWG521   36000.0   9681
# ...          ...       ...    ...
# 1247618  EZY84ZA   19150.0      1
# 1247619  EZY84ZA   19175.0      1
# 1247620  EZY84ZA   19200.0      1
# 1247621  EZY84ZA   19225.0      1
# 1247622   AAL110    2500.0      1
#
# [1247623 rows x 3 columns]

# %% [markdown]
# # 5 - AdvancedColumnMethods <a class="anchor" id="s6"></a> [↩️TOC](#toc)

# %% [markdown]
# Ranking Methods - Rank is for identifying ties

# %%
df[['callsign']].rank()
# Out:
#          callsign
# 0        765034.5
# 1        765034.5
# 2        765034.5
# 3        765034.5
# 4        765034.5
# ...           ...
# 4344354  908864.5
# 4344355  908864.5
# 4344356  908864.5
# 4344357  908864.5
# 4344358  908864.5
#
# [4344359 rows x 1 columns]

# %%
df[['callsign']].rank(method='dense')
# Out:
#          callsign
# 0           131.0
# 1           131.0
# 2           131.0
# 3           131.0
# 4           131.0
# ...           ...
# 4344354     154.0
# 4344355     154.0
# 4344356     154.0
# 4344357     154.0
# 4344358     154.0
#
# [4344359 rows x 1 columns]

# %%
df[['callsign']].rank(method='first')
# Out:
#          callsign
# 0        763594.0
# 1        763595.0
# 2        763596.0
# 3        763597.0
# 4        763598.0
# ...           ...
# 4344354  912588.0
# 4344355  912589.0
# 4344356  912590.0
# 4344357  912591.0
# 4344358  912592.0
#
# [4344359 rows x 1 columns]

# %% [markdown]
# Shifting Values

# %%
df[['callsign']].shift(1)
# Out:
#         callsign
# 0           None
# 1        ARG1511
# 2        ARG1511
# 3        ARG1511
# 4        ARG1511
# ...          ...
# 4344354  ASH6299
# 4344355  ASH6299
# 4344356  ASH6299
# 4344357  ASH6299
# 4344358  ASH6299
#
# [4344359 rows x 1 columns]

# %%
df[['callsign']].shift(-1, fill_value=0)
# Out:
#         callsign
# 0        ARG1511
# 1        ARG1511
# 2        ARG1511
# 3        ARG1511
# 4        ARG1511
# ...          ...
# 4344354  ASH6299
# 4344355  ASH6299
# 4344356  ASH6299
# 4344357  ASH6299
# 4344358        0
#
# [4344359 rows x 1 columns]

# %% [markdown]
# Cumulative Sum

# %%
df[['callsign']].cummax()
# Out:
#         callsign
# 0        ARG1511
# 1        ARG1511
# 2        ARG1511
# 3        ARG1511
# 4        ARG1511
# ...          ...
# 4344354   XOJ546
# 4344355   XOJ546
# 4344356   XOJ546
# 4344357   XOJ546
# 4344358   XOJ546
#
# [4344359 rows x 1 columns]

# %% [markdown]
# # 6 - RollingMethods <a class="anchor" id="s7"></a> [↩️TOC](#toc)
#
# - Used mostly with time series data

# %%
df.describe()
# Out:
#            altitude   groundspeed      latitude     longitude         track  \
# count  4.344359e+06  4.307312e+06  4.344359e+06  4.344359e+06  4.307312e+06
# mean   2.653439e+04  3.944624e+02  4.010783e+01 -4.393507e+01  1.927143e+02
# std    1.212769e+04  1.285338e+02  1.492686e+01  5.537757e+01  1.062650e+02
# min   -5.750000e+02  2.828425e+00 -3.866559e+01 -1.565582e+02  0.000000e+00
# 25%    1.647500e+04  3.398423e+02  3.549571e+01 -9.158867e+01  9.294816e+01
# 50%    3.200000e+04  4.186379e+02  4.220419e+01 -6.188072e+01  2.094500e+02
# 75%    3.600000e+04  4.637420e+02  4.920561e+01  1.862626e+00  2.851302e+02
# max    1.155000e+05  4.535941e+03  6.682288e+01  1.764965e+02  3.600000e+02
#
#        vertical_rate
# count   4.307312e+06
# mean   -3.354702e+01
# std     1.772641e+03
# min    -2.302500e+05
# 25%    -6.400000e+01
# 50%     0.000000e+00
# 75%     0.000000e+00
# max     1.235200e+04

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4344359 entries, 0 to 4344358
# Data columns (total 11 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   timestamp      datetime64[us, UTC]
#  1   altitude       float64
#  2   callsign       object
#  3   flight_id      object
#  4   groundspeed    float64
#  5   icao24         object
#  6   latitude       float64
#  7   longitude      float64
#  8   squawk         object
#  9   track          float64
#  10  vertical_rate  float64
# dtypes: datetime64[us, UTC](1), float64(6), object(4)
# memory usage: 364.6+ MB

# %%
df.head()
# Out:
#                   timestamp  altitude callsign         flight_id  groundspeed  \
# 0 2018-01-01 12:29:49+00:00   11300.0  ARG1511  ARG1511_20180101   309.885195
# 1 2018-01-01 12:29:50+00:00   11375.0  ARG1511  ARG1511_20180101   310.264709
# 2 2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101   310.644223
# 3 2018-01-01 12:29:52+00:00   11500.0  ARG1511  ARG1511_20180101   311.192793
# 4 2018-01-01 12:29:53+00:00   11550.0  ARG1511  ARG1511_20180101   311.741363
#
#    icao24   latitude  longitude squawk       track  vertical_rate
# 0  e06442 -31.449051 -63.963318   7700  130.441641    3008.000000
# 1  e06442 -31.450453 -63.961432   7700  130.441641    3040.000000
# 2  e06442 -31.451856 -63.959546   7700  130.441641    3072.000000
# 3  e06442 -31.452843 -63.958193   7700  130.440361    3074.742857
# 4  e06442 -31.453831 -63.956840   7700  130.439081    3077.485714

# %%
df[['altitude']].rolling(window=5).mean()
# Out:
#              altitude
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4        11435.000000
# ...               ...
# 4344354    656.250000
# 4344355    655.208333
# 4344356    654.166667
# 4344357    653.125000
# 4344358    652.083333
#
# [4344359 rows x 1 columns]

# %% [markdown]
# Cliping data based on a limit

# %%
df[['timestamp']].clip(1000)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py:983 in _cmp_method    │
# │                                                                                                  │
# │    980 │   │   │   return op(self.ravel(), other.ravel()).reshape(self.shape)                    │
# │    981 │   │                                                                                     │
# │    982 │   │   try:                                                                              │
# │ ❱  983 │   │   │   other = self._validate_comparison_value(other)                                │
# │    984 │   │   except InvalidComparison:                                                         │
# │    985 │   │   │   return invalid_comparison(self, other, op)                                    │
# ...

# %% [markdown]
# # 7 - GroupbyMethods <a class="anchor" id="s8"></a> [↩️TOC](#toc)
#
# Mostly for categorical values

# %%
df.head()
# Out:
#                   timestamp  altitude callsign         flight_id  groundspeed  \
# 0 2018-01-01 12:29:49+00:00   11300.0  ARG1511  ARG1511_20180101   309.885195
# 1 2018-01-01 12:29:50+00:00   11375.0  ARG1511  ARG1511_20180101   310.264709
# 2 2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101   310.644223
# 3 2018-01-01 12:29:52+00:00   11500.0  ARG1511  ARG1511_20180101   311.192793
# 4 2018-01-01 12:29:53+00:00   11550.0  ARG1511  ARG1511_20180101   311.741363
#
#    icao24   latitude  longitude squawk       track  vertical_rate
# 0  e06442 -31.449051 -63.963318   7700  130.441641    3008.000000
# 1  e06442 -31.450453 -63.961432   7700  130.441641    3040.000000
# 2  e06442 -31.451856 -63.959546   7700  130.441641    3072.000000
# 3  e06442 -31.452843 -63.958193   7700  130.440361    3074.742857
# 4  e06442 -31.453831 -63.956840   7700  130.439081    3077.485714

# %% [markdown]
# Below grouping the arilines with average ground speed.
# - Then we want to get their mean
# - We can run the agg function to get multiple

# %%
df.groupby('callsign')[['groundspeed']].mean()
# Out:
#           groundspeed
# callsign
# AAL110     435.590866
# AAL1188    352.970968
# AAL1328    387.433789
# AAL1612    393.682792
# AAL1619    395.440767
# ...               ...
# WOW9625    316.171389
# WZZ6TM     403.084699
# WZZ8HT     408.626742
# XOJ545     429.382628
# XOJ546     436.775903
#
# [823 rows x 1 columns]

# %%
df.groupby('callsign')[['groundspeed']].agg(['mean', 'min', 'max'])
# Out:
#          groundspeed
#                 mean         min         max
# callsign
# AAL110    435.590866  178.899259  529.461534
# AAL1188   352.970968  131.003704  471.444181
# AAL1328   387.433789  138.003504  452.682721
# AAL1612   393.682792  145.003323  434.065288
# AAL1619   395.440767  169.073802  450.959697
# ...              ...         ...         ...
# WOW9625   316.171389  122.999894  416.601368
# WZZ6TM    403.084699  134.658712  468.539882
# WZZ8HT    408.626742  150.442550  460.108285
# XOJ545    429.382628  107.041955  493.063464
# XOJ546    436.775903  137.058263  483.761920
#
# [823 rows x 3 columns]

# %%
df.groupby('callsign')[['groundspeed']].agg(['mean', 'min', 'max'])
# Out:
#          groundspeed                              altitude
#                 mean         min         max          mean     min      max
# callsign
# AAL110    435.590866  178.899259  529.461534  21101.803519  2500.0  27000.0
# AAL1188   352.970968  131.003704  471.444181  21510.429699   900.0  34000.0
# AAL1328   387.433789  138.003504  452.682721  29066.321193  1400.0  38000.0
# AAL1612   393.682792  145.003323  434.065288  30562.413768   775.0  36000.0
# AAL1619   395.440767  169.073802  450.959697  26820.368890  1775.0  34000.0
# ...              ...         ...         ...           ...     ...      ...
# WOW9625   316.171389  122.999894  416.601368  16159.705882  -150.0  34000.0
# WZZ6TM    403.084699  134.658712  468.539882  27476.408025   312.5  36050.0
# WZZ8HT    408.626742  150.442550  460.108285  29046.075912   325.0  34050.0
# XOJ545    429.382628  107.041955  493.063464  37718.346997   775.0  45050.0
# ...

# %%
# Flattening multi index columns 
dfag1 = df.groupby('callsign')[['groundspeed']].agg(['mean', 'min', 'max'])

# %%
dfag1.columns
# Out:
# MultiIndex([('groundspeed', 'mean'),
#             ('groundspeed',  'min'),
#             ('groundspeed',  'max')],
#            )

# %% [markdown]
# Convert to list of tuples

# %%
dfag1.columns.to_flat_index()
# Out:
# Index([('groundspeed', 'mean'), ('groundspeed', 'min'),
#        ('groundspeed', 'max')],
#       dtype='object')

# %%
dfag1.colums = ['_'.join(c) for c in dfag1.columns]

# %% [markdown]
# # 9 - NewColumns <a class="anchor" id="s9"></a> [↩️TOC](#toc)

# %% [markdown]
# Now making new columns in the data

# %%
df.head()
# Out:
#                   timestamp  altitude callsign         flight_id  groundspeed  \
# 0 2018-01-01 12:29:49+00:00   11300.0  ARG1511  ARG1511_20180101   309.885195
# 1 2018-01-01 12:29:50+00:00   11375.0  ARG1511  ARG1511_20180101   310.264709
# 2 2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101   310.644223
# 3 2018-01-01 12:29:52+00:00   11500.0  ARG1511  ARG1511_20180101   311.192793
# 4 2018-01-01 12:29:53+00:00   11550.0  ARG1511  ARG1511_20180101   311.741363
#
#    icao24   latitude  longitude squawk       track  vertical_rate
# 0  e06442 -31.449051 -63.963318   7700  130.441641    3008.000000
# 1  e06442 -31.450453 -63.961432   7700  130.441641    3040.000000
# 2  e06442 -31.451856 -63.959546   7700  130.441641    3072.000000
# 3  e06442 -31.452843 -63.958193   7700  130.440361    3074.742857
# 4  e06442 -31.453831 -63.956840   7700  130.439081    3077.485714

# %% [markdown]
# Here we are adding a new column, by performing an operation on one column

# %%
df['altpanty'] = df['altitude'] / 90

# %%
df.head()
# Out:
#                   timestamp  altitude callsign         flight_id  groundspeed  \
# 0 2018-01-01 12:29:49+00:00   11300.0  ARG1511  ARG1511_20180101   309.885195
# 1 2018-01-01 12:29:50+00:00   11375.0  ARG1511  ARG1511_20180101   310.264709
# 2 2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101   310.644223
# 3 2018-01-01 12:29:52+00:00   11500.0  ARG1511  ARG1511_20180101   311.192793
# 4 2018-01-01 12:29:53+00:00   11550.0  ARG1511  ARG1511_20180101   311.741363
#
#    icao24   latitude  longitude squawk       track  vertical_rate    altpanty
# 0  e06442 -31.449051 -63.963318   7700  130.441641    3008.000000  125.555556
# 1  e06442 -31.450453 -63.961432   7700  130.441641    3040.000000  126.388889
# 2  e06442 -31.451856 -63.959546   7700  130.441641    3072.000000  127.222222
# 3  e06442 -31.452843 -63.958193   7700  130.440361    3074.742857  127.777778
# 4  e06442 -31.453831 -63.956840   7700  130.439081    3077.485714  128.333333

# %% [markdown]
# This will directly create a new object

# %%
df.assign(al3 = df['altitude']/2)
# Out:
#                         timestamp      altitude callsign         flight_id  \
# 0       2018-01-01 12:29:49+00:00  11300.000000  ARG1511  ARG1511_20180101
# 1       2018-01-01 12:29:50+00:00  11375.000000  ARG1511  ARG1511_20180101
# 2       2018-01-01 12:29:51+00:00  11450.000000  ARG1511  ARG1511_20180101
# 3       2018-01-01 12:29:52+00:00  11500.000000  ARG1511  ARG1511_20180101
# 4       2018-01-01 12:29:53+00:00  11550.000000  ARG1511  ARG1511_20180101
# ...                           ...           ...      ...               ...
# 4344354 2020-01-29 04:09:48+00:00    654.166667  ASH6299  ASH6299_20200129
# 4344355 2020-01-29 04:09:49+00:00    653.125000  ASH6299  ASH6299_20200129
# 4344356 2020-01-29 04:09:50+00:00    652.083333  ASH6299  ASH6299_20200129
# 4344357 2020-01-29 04:09:51+00:00    651.041667  ASH6299  ASH6299_20200129
# 4344358 2020-01-29 04:09:52+00:00    650.000000  ASH6299  ASH6299_20200129
#
# ...

# %% [markdown]
# # 10-SortData <a class="anchor" id="s10"></a> [↩️TOC](#toc)

# %% [markdown]
# => Sorting on the altitude , ascending

# %%
df.sort_values('altitude')
# Out:
#                         timestamp       altitude callsign         flight_id  \
# 171514  2018-02-26 12:38:09+00:00    -575.000000  SHT16ED  SHT16ED_20180226
# 171515  2018-02-26 12:38:10+00:00    -574.193548  SHT16ED  SHT16ED_20180226
# 171516  2018-02-26 12:38:11+00:00    -573.387097  SHT16ED  SHT16ED_20180226
# 171517  2018-02-26 12:38:12+00:00    -572.580645  SHT16ED  SHT16ED_20180226
# 171518  2018-02-26 12:38:13+00:00    -571.774194  SHT16ED  SHT16ED_20180226
# ...                           ...            ...      ...               ...
# 1581838 2018-12-11 06:44:32+00:00  115500.000000    UAL14    UAL14_20181211
# 1581837 2018-12-11 06:44:31+00:00  115500.000000    UAL14    UAL14_20181211
# 1581836 2018-12-11 06:44:30+00:00  115500.000000    UAL14    UAL14_20181211
# 1581834 2018-12-11 06:44:28+00:00  115500.000000    UAL14    UAL14_20181211
# 1581823 2018-12-11 06:44:17+00:00  115500.000000    UAL14    UAL14_20181211
#
# ...

# %%
df.plot(x='callsign', y='altitude')
# Out:
# <Axes: xlabel='callsign'>

# %%
df.plot(x='callsign', y='altitude', kind='scatter')
# Out:
# <Axes: xlabel='callsign', ylabel='altitude'>

# %%
df.describe()
# Out:
#            altitude   groundspeed      latitude     longitude         track  \
# count  4.344359e+06  4.307312e+06  4.344359e+06  4.344359e+06  4.307312e+06
# mean   2.653439e+04  3.944624e+02  4.010783e+01 -4.393507e+01  1.927143e+02
# std    1.212769e+04  1.285338e+02  1.492686e+01  5.537757e+01  1.062650e+02
# min   -5.750000e+02  2.828425e+00 -3.866559e+01 -1.565582e+02  0.000000e+00
# 25%    1.647500e+04  3.398423e+02  3.549571e+01 -9.158867e+01  9.294816e+01
# 50%    3.200000e+04  4.186379e+02  4.220419e+01 -6.188072e+01  2.094500e+02
# 75%    3.600000e+04  4.637420e+02  4.920561e+01  1.862626e+00  2.851302e+02
# max    1.155000e+05  4.535941e+03  6.682288e+01  1.764965e+02  3.600000e+02
#
#        vertical_rate      altpanty
# count   4.307312e+06  4.344359e+06
# mean   -3.354702e+01  2.948266e+02
# std     1.772641e+03  1.347521e+02
# min    -2.302500e+05 -6.388889e+00
# 25%    -6.400000e+01  1.830556e+02
# 50%     0.000000e+00  3.555556e+02
# ...

# %% [markdown]
# 1. Sorting data iwth a subset of the columns , which one column will be the index

# %%
df[['altitude', 'callsign']].sort_values('altitude')
# Out:
#               altitude callsign
# 171514     -575.000000  SHT16ED
# 171515     -574.193548  SHT16ED
# 171516     -573.387097  SHT16ED
# 171517     -572.580645  SHT16ED
# 171518     -571.774194  SHT16ED
# ...                ...      ...
# 1581838  115500.000000    UAL14
# 1581837  115500.000000    UAL14
# 1581836  115500.000000    UAL14
# 1581834  115500.000000    UAL14
# 1581823  115500.000000    UAL14
#
# [4344359 rows x 2 columns]

# %% [markdown]
# Ascending to false

# %%
df[['altitude', 'callsign']].sort_values('altitude', ascending=False)
# Out:
#               altitude callsign
# 1581819  115500.000000    UAL14
# 1581830  115500.000000    UAL14
# 1581820  115500.000000    UAL14
# 1581823  115500.000000    UAL14
# 1581824  115500.000000    UAL14
# ...                ...      ...
# 171518     -571.774194  SHT16ED
# 171517     -572.580645  SHT16ED
# 171516     -573.387097  SHT16ED
# 171515     -574.193548  SHT16ED
# 171514     -575.000000  SHT16ED
#
# [4344359 rows x 2 columns]

# %% [markdown]
# Sortina and dropping NAN Value

# %%
df[['altitude', 'callsign']].sort_values('altitude', ascending=False).reset_index(drop=True)
# Out:
#               altitude callsign
# 0        115500.000000    UAL14
# 1        115500.000000    UAL14
# 2        115500.000000    UAL14
# 3        115500.000000    UAL14
# 4        115500.000000    UAL14
# ...                ...      ...
# 4344354    -571.774194  SHT16ED
# 4344355    -572.580645  SHT16ED
# 4344356    -573.387097  SHT16ED
# 4344357    -574.193548  SHT16ED
# 4344358    -575.000000  SHT16ED
#
# [4344359 rows x 2 columns]

# %%
df[['altitude', 'callsign']]
# Out:
#              altitude callsign
# 0        11300.000000  ARG1511
# 1        11375.000000  ARG1511
# 2        11450.000000  ARG1511
# 3        11500.000000  ARG1511
# 4        11550.000000  ARG1511
# ...               ...      ...
# 4344354    654.166667  ASH6299
# 4344355    653.125000  ASH6299
# 4344356    652.083333  ASH6299
# 4344357    651.041667  ASH6299
# 4344358    650.000000  ASH6299
#
# [4344359 rows x 2 columns]

# %% [markdown]
# Sorting by index if it is numeic

# %%
df[['altitude', 'callsign']].sort_index()
# Out:
#              altitude callsign
# 0        11300.000000  ARG1511
# 1        11375.000000  ARG1511
# 2        11450.000000  ARG1511
# 3        11500.000000  ARG1511
# 4        11550.000000  ARG1511
# ...               ...      ...
# 4344354    654.166667  ASH6299
# 4344355    653.125000  ASH6299
# 4344356    652.083333  ASH6299
# 4344357    651.041667  ASH6299
# 4344358    650.000000  ASH6299
#
# [4344359 rows x 2 columns]

# %% [markdown]
# # 11-MissingData <a class="anchor" id="s11"></a> [↩️TOC](#toc)

# %%
df.describe()
# Out:
#            altitude   groundspeed      latitude     longitude         track  \
# count  4.344359e+06  4.307312e+06  4.344359e+06  4.344359e+06  4.307312e+06
# mean   2.653439e+04  3.944624e+02  4.010783e+01 -4.393507e+01  1.927143e+02
# std    1.212769e+04  1.285338e+02  1.492686e+01  5.537757e+01  1.062650e+02
# min   -5.750000e+02  2.828425e+00 -3.866559e+01 -1.565582e+02  0.000000e+00
# 25%    1.647500e+04  3.398423e+02  3.549571e+01 -9.158867e+01  9.294816e+01
# 50%    3.200000e+04  4.186379e+02  4.220419e+01 -6.188072e+01  2.094500e+02
# 75%    3.600000e+04  4.637420e+02  4.920561e+01  1.862626e+00  2.851302e+02
# max    1.155000e+05  4.535941e+03  6.682288e+01  1.764965e+02  3.600000e+02
#
#        vertical_rate      altpanty
# count   4.307312e+06  4.344359e+06
# mean   -3.354702e+01  2.948266e+02
# std     1.772641e+03  1.347521e+02
# min    -2.302500e+05 -6.388889e+00
# 25%    -6.400000e+01  1.830556e+02
# 50%     0.000000e+00  3.555556e+02
# ...

# %% [markdown]
# Finding Missing data

# %%
df.isna()
# Out:
#          timestamp  altitude  callsign  flight_id  groundspeed  icao24  \
# 0            False     False     False      False        False   False
# 1            False     False     False      False        False   False
# 2            False     False     False      False        False   False
# 3            False     False     False      False        False   False
# 4            False     False     False      False        False   False
# ...            ...       ...       ...        ...          ...     ...
# 4344354      False     False     False      False        False   False
# 4344355      False     False     False      False        False   False
# 4344356      False     False     False      False        False   False
# 4344357      False     False     False      False        False   False
# 4344358      False     False     False      False        False   False
#
#          latitude  longitude  squawk  track  vertical_rate  altpanty
# ...

# %%
df.isna().sum()
# Out:
# timestamp            0
# altitude             0
# callsign             0
# flight_id            0
# groundspeed      37047
# icao24               0
# latitude             0
# longitude            0
# squawk               0
# track            37047
# vertical_rate    37047
# altpanty             0
# dtype: int64

# %%
df[['groundspeed', 'track', 'vertical_rate']].isna().sum()
# Out:
# groundspeed      37047
# track            37047
# vertical_rate    37047
# dtype: int64

# %%
df[['groundspeed', 'track', 'vertical_rate']].dropna()
# Out:
#          groundspeed       track  vertical_rate
# 0         309.885195  130.441641    3008.000000
# 1         310.264709  130.441641    3040.000000
# 2         310.644223  130.441641    3072.000000
# 3         311.192793  130.440361    3074.742857
# 4         311.741363  130.439081    3077.485714
# ...              ...         ...            ...
# 4344354   137.440778  274.590543    -704.000000
# 4344355   137.440778  274.590543    -704.000000
# 4344356   137.440778  274.590543    -704.000000
# 4344357   137.440778  274.590543    -704.000000
# 4344358   137.440778  274.590543    -704.000000
#
# [4307312 rows x 3 columns]

# %%
df[['groundspeed', 'track', 'vertical_rate']].isna().sum()
# Out:
# groundspeed      37047
# track            37047
# vertical_rate    37047
# dtype: int64

# %% [markdown]
# Dropping the Null Values

# %% [markdown]
# # Extracting rows with NaN

# %%
df[df['track'].isna()]
# Out:
#                         timestamp  altitude callsign         flight_id  \
# 840722  2018-07-19 21:10:55+00:00    9200.0  BAW2605  BAW2605_20180719
# 840723  2018-07-19 21:10:56+00:00    9225.0  BAW2605  BAW2605_20180719
# 840724  2018-07-19 21:10:57+00:00    9250.0  BAW2605  BAW2605_20180719
# 840725  2018-07-19 21:10:58+00:00    9250.0  BAW2605  BAW2605_20180719
# 840726  2018-07-19 21:10:59+00:00    9300.0  BAW2605  BAW2605_20180719
# ...                           ...       ...      ...               ...
# 4234935 2020-01-14 09:07:10+00:00   34500.0   KLM85R   KLM85R_20200114
# 4234936 2020-01-14 09:07:19+00:00   34500.0   KLM85R   KLM85R_20200114
# 4234937 2020-01-14 09:07:30+00:00   34500.0   KLM85R   KLM85R_20200114
# 4234938 2020-01-14 09:07:31+00:00   34500.0   KLM85R   KLM85R_20200114
# 4234939 2020-01-14 09:08:20+00:00   34500.0   KLM85R   KLM85R_20200114
#
#          groundspeed  icao24   latitude  longitude squawk  track  \
# ...

# %%
df[['groundspeed', 'track', 'vertical_rate']].dropna()
# Out:
#          groundspeed       track  vertical_rate
# 0         309.885195  130.441641    3008.000000
# 1         310.264709  130.441641    3040.000000
# 2         310.644223  130.441641    3072.000000
# 3         311.192793  130.440361    3074.742857
# 4         311.741363  130.439081    3077.485714
# ...              ...         ...            ...
# 4344354   137.440778  274.590543    -704.000000
# 4344355   137.440778  274.590543    -704.000000
# 4344356   137.440778  274.590543    -704.000000
# 4344357   137.440778  274.590543    -704.000000
# 4344358   137.440778  274.590543    -704.000000
#
# [4307312 rows x 3 columns]

# %%
dfC = df[['groundspeed', 'track', 'vertical_rate']].dropna()

# %% [markdown]
# Removing

# %%
dfC[['groundspeed', 'track', 'vertical_rate']].isna().sum()
# Out:
# groundspeed      0
# track            0
# vertical_rate    0
# dtype: int64

# %%
# filling the na values 
df[['groundspeed', 'track', 'vertical_rate']].fillna(9)
# Out:
#          groundspeed       track  vertical_rate
# 0         309.885195  130.441641    3008.000000
# 1         310.264709  130.441641    3040.000000
# 2         310.644223  130.441641    3072.000000
# 3         311.192793  130.440361    3074.742857
# 4         311.741363  130.439081    3077.485714
# ...              ...         ...            ...
# 4344354   137.440778  274.590543    -704.000000
# 4344355   137.440778  274.590543    -704.000000
# 4344356   137.440778  274.590543    -704.000000
# 4344357   137.440778  274.590543    -704.000000
# 4344358   137.440778  274.590543    -704.000000
#
# [4344359 rows x 3 columns]

# %% [markdown]
# This following code will fill the NAN witht the average value

# %%
df[['groundspeed', 'track', 'vertical_rate']].fillna(df['track'].mean())
# Out:
#          groundspeed       track  vertical_rate
# 0         309.885195  130.441641    3008.000000
# 1         310.264709  130.441641    3040.000000
# 2         310.644223  130.441641    3072.000000
# 3         311.192793  130.440361    3074.742857
# 4         311.741363  130.439081    3077.485714
# ...              ...         ...            ...
# 4344354   137.440778  274.590543    -704.000000
# 4344355   137.440778  274.590543    -704.000000
# 4344356   137.440778  274.590543    -704.000000
# 4344357   137.440778  274.590543    -704.000000
# 4344358   137.440778  274.590543    -704.000000
#
# [4344359 rows x 3 columns]

# %% [markdown]
# # 12-CombiningData <a class="anchor" id="s12"></a> [↩️TOC](#toc)

# %%
df.describe()
# Out:
#            altitude   groundspeed      latitude     longitude         track  \
# count  4.344359e+06  4.307312e+06  4.344359e+06  4.344359e+06  4.307312e+06
# mean   2.653439e+04  3.944624e+02  4.010783e+01 -4.393507e+01  1.927143e+02
# std    1.212769e+04  1.285338e+02  1.492686e+01  5.537757e+01  1.062650e+02
# min   -5.750000e+02  2.828425e+00 -3.866559e+01 -1.565582e+02  0.000000e+00
# 25%    1.647500e+04  3.398423e+02  3.549571e+01 -9.158867e+01  9.294816e+01
# 50%    3.200000e+04  4.186379e+02  4.220419e+01 -6.188072e+01  2.094500e+02
# 75%    3.600000e+04  4.637420e+02  4.920561e+01  1.862626e+00  2.851302e+02
# max    1.155000e+05  4.535941e+03  6.682288e+01  1.764965e+02  3.600000e+02
#
#        vertical_rate      altpanty
# count   4.307312e+06  4.344359e+06
# mean   -3.354702e+01  2.948266e+02
# std     1.772641e+03  1.347521e+02
# min    -2.302500e+05 -6.388889e+00
# 25%    -6.400000e+01  1.830556e+02
# 50%     0.000000e+00  3.555556e+02
# ...

# %%
df.head()
# Out:
#                   timestamp  altitude callsign         flight_id  groundspeed  \
# 0 2018-01-01 12:29:49+00:00   11300.0  ARG1511  ARG1511_20180101   309.885195
# 1 2018-01-01 12:29:50+00:00   11375.0  ARG1511  ARG1511_20180101   310.264709
# 2 2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101   310.644223
# 3 2018-01-01 12:29:52+00:00   11500.0  ARG1511  ARG1511_20180101   311.192793
# 4 2018-01-01 12:29:53+00:00   11550.0  ARG1511  ARG1511_20180101   311.741363
#
#    icao24   latitude  longitude squawk       track  vertical_rate    altpanty
# 0  e06442 -31.449051 -63.963318   7700  130.441641    3008.000000  125.555556
# 1  e06442 -31.450453 -63.961432   7700  130.441641    3040.000000  126.388889
# 2  e06442 -31.451856 -63.959546   7700  130.441641    3072.000000  127.222222
# 3  e06442 -31.452843 -63.958193   7700  130.440361    3074.742857  127.777778
# 4  e06442 -31.453831 -63.956840   7700  130.439081    3077.485714  128.333333

# %%
df.tail()
# Out:
#                         timestamp    altitude callsign         flight_id  \
# 4344354 2020-01-29 04:09:48+00:00  654.166667  ASH6299  ASH6299_20200129
# 4344355 2020-01-29 04:09:49+00:00  653.125000  ASH6299  ASH6299_20200129
# 4344356 2020-01-29 04:09:50+00:00  652.083333  ASH6299  ASH6299_20200129
# 4344357 2020-01-29 04:09:51+00:00  651.041667  ASH6299  ASH6299_20200129
# 4344358 2020-01-29 04:09:52+00:00  650.000000  ASH6299  ASH6299_20200129
#
#          groundspeed  icao24   latitude  longitude squawk       track  \
# 4344354   137.440778  ac2bb8  40.002762 -82.899621   2756  274.590543
# 4344355   137.440778  ac2bb8  40.002789 -82.900084   2756  274.590543
# 4344356   137.440778  ac2bb8  40.002816 -82.900547   2756  274.590543
# 4344357   137.440778  ac2bb8  40.002842 -82.901011   2756  274.590543
# 4344358   137.440778  ac2bb8  40.002869 -82.901474   2756  274.590543
#
#          vertical_rate  altpanty
# 4344354         -704.0  7.268519
# 4344355         -704.0  7.256944
# ...

# %% [markdown]
# Creating two new dataframes

# %% [markdown]
# 1. The `.copy()` command will make copies of the dataset

# %%
df1 = df[df['callsign'].str.contains('^ARG', na=False)].copy()
df2 = df[df['callsign'].str.contains('^ASH', na=False)].copy()

# %%
df1.head() 
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39783 entries, 0 to 4092076
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      39783 non-null  datetime64[us, UTC]
#  1   altitude       39783 non-null  float64
#  2   callsign       39783 non-null  object
#  3   flight_id      39783 non-null  object
#  4   groundspeed    39783 non-null  float64
#  5   icao24         39783 non-null  object
#  6   latitude       39783 non-null  float64
#  7   longitude      39783 non-null  float64
#  8   squawk         39783 non-null  object
#  9   track          39783 non-null  float64
#  10  vertical_rate  39783 non-null  float64
#  11  altpanty       39783 non-null  float64
# dtypes: datetime64[us, UTC](1), float64(7), object(4)
# memory usage: 3.9+ MB

# %%
df1.shape
# Out:
# (39783, 12)

# %%
df2.shape
# Out:
# (61140, 12)

# %%
df2.describe()
# Out:
#            altitude   groundspeed      latitude     longitude         track  \
# count  61140.000000  61140.000000  61140.000000  61140.000000  61140.000000
# mean   24853.836072    383.611089     34.552485    -89.483595    156.546647
# std    11439.152664     99.092178      3.424329      6.189107     93.030485
# min        0.000000     58.008570     26.050074    -98.234200      0.000000
# 25%    15180.787492    339.055095     31.557302    -95.162466     72.704661
# 50%    31814.610662    378.529725     35.226609    -90.656982    137.338280
# 75%    34000.000000    472.284880     37.512678    -84.227720    240.482657
# max    38025.000000    584.061992     41.287878    -77.435608    360.000000
#
#        vertical_rate      altpanty
# count   61140.000000  61140.000000
# mean       64.527778    276.153734
# std       952.642767    127.101696
# min     -3776.000000      0.000000
# 25%       -64.000000    168.675417
# 50%         0.000000    353.495674
# ...

# %%
df1.describe()
# Out:
#             altitude   groundspeed      latitude     longitude         track  \
# count   39783.000000  39783.000000  39783.000000  39783.000000  39783.000000
# mean    30635.156348    404.698181    -28.810537    -60.700038    192.512793
# std     12864.971776    102.880923      8.844130      6.253884     86.517379
# min       -25.000000    117.153644    -34.817908    -70.823476      2.653320
# 25%     24573.750000    333.407870    -34.121296    -63.782856    103.832827
# 50%     38000.000000    449.604994    -33.402377    -60.952034    173.408918
# 75%     39000.000000    472.098099    -30.627394    -59.153987    277.168275
# max    114600.000000    555.816036     -6.780985    -35.352305    349.713829
#
#        vertical_rate      altpanty
# count   39783.000000  39783.000000
# mean     -224.582091    340.390626
# std      1039.071365    142.944131
# min     -5312.000000     -0.277778
# 25%      -448.000000    273.041667
# 50%         0.000000    422.222222
# ...

# %% [markdown]
# Combining new dataset

# %%
pd.concat([df1, df2])
# Out:
#                         timestamp      altitude callsign         flight_id  \
# 0       2018-01-01 12:29:49+00:00  11300.000000  ARG1511  ARG1511_20180101
# 1       2018-01-01 12:29:50+00:00  11375.000000  ARG1511  ARG1511_20180101
# 2       2018-01-01 12:29:51+00:00  11450.000000  ARG1511  ARG1511_20180101
# 3       2018-01-01 12:29:52+00:00  11500.000000  ARG1511  ARG1511_20180101
# 4       2018-01-01 12:29:53+00:00  11550.000000  ARG1511  ARG1511_20180101
# ...                           ...           ...      ...               ...
# 4344354 2020-01-29 04:09:48+00:00    654.166667  ASH6299  ASH6299_20200129
# 4344355 2020-01-29 04:09:49+00:00    653.125000  ASH6299  ASH6299_20200129
# 4344356 2020-01-29 04:09:50+00:00    652.083333  ASH6299  ASH6299_20200129
# 4344357 2020-01-29 04:09:51+00:00    651.041667  ASH6299  ASH6299_20200129
# 4344358 2020-01-29 04:09:52+00:00    650.000000  ASH6299  ASH6299_20200129
#
# ...

# %%
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

# %% [markdown]
# # Stacking
# 1. `axis=0` = This will stack them one top of the other
# 2. `axis=1` = This will put tables side by side

# %%
pd.concat([df1, df2], axis=1)
# Out:
#                       timestamp  altitude callsign         flight_id  \
# 0     2018-01-01 12:29:49+00:00   11300.0  ARG1511  ARG1511_20180101
# 1     2018-01-01 12:29:50+00:00   11375.0  ARG1511  ARG1511_20180101
# 2     2018-01-01 12:29:51+00:00   11450.0  ARG1511  ARG1511_20180101
# 3     2018-01-01 12:29:52+00:00   11500.0  ARG1511  ARG1511_20180101
# 4     2018-01-01 12:29:53+00:00   11550.0  ARG1511  ARG1511_20180101
# ...                         ...       ...      ...               ...
# 61135                       NaT       NaN      NaN               NaN
# 61136                       NaT       NaN      NaN               NaN
# 61137                       NaT       NaN      NaN               NaN
# 61138                       NaT       NaN      NaN               NaN
# 61139                       NaT       NaN      NaN               NaN
#
#        groundspeed  icao24   latitude  longitude squawk       track  \
# 0       309.885195  e06442 -31.449051 -63.963318   7700  130.441641
# ...

# %% [markdown]
# # 13-MergeData <a class="anchor" id="s13"></a> [↩️TOC](#toc)

# %%
dfm1 = df.groupby(['callsign', 'altitude'])[['altpanty']].mean().reset_index()
dfm2 = df.groupby(['callsign', 'altitude'])[['groundspeed']].mean().reset_index()
